# %%
# !pip install jovian --upgrade --quiet
import jovian
# Out:
#      |████████████████████████████████| 68 kB 1.3 MB/s
# ...

# %%
tests=[{'input': {'nums': [19, 25, 29, 3, 5, 6, 7, 9, 11, 14]}, 'output': 3},
 {'input': {'nums': [15, 16, 17, 18, 19, 1, 2, 3]}, 'output': 5},
 {'input': {'nums': [1, 2, 3, 4, 5, 6, 7, 8]}, 'output': 0},
 {'input': {'nums': [10, 1, 2, 3, 4, 5]}, 'output': 1},
 {'input': {'nums': [2, 3, 4, 5, 1]}, 'output': 4},
 {'input': {'nums': [2, 3, 4, 5, 0]}, 'output': 4},
 {'input': {'nums': []}, 'output': 0},
 {'input': {'nums': [1]}, 'output': 0}]

# %% [markdown]
# # **Linear Search**

# %%
def count_rotations_linear(nums):
    position = 0                # What is the intial value of position?
    if len(nums) == 0 or len(nums)==1:
      return 0
    else:
      while position < len(nums):                     # When should the loop be terminated?
        
        # Success criteria: check whether the number at the current position is smaller than the one before it
          if position > 0 and nums[position] < nums[position-1]:   # How to perform the check?
              return position
        
        # Move to the next position
          position += 1
          if position == len(nums):
            return 0
      return -1

# %%
from jovian.pythondsa import evaluate_test_cases

# %%
linear_search_result = evaluate_test_cases(count_rotations_linear, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'nums': [19, 25, 29, 3, 5, 6, 7, 9, 11, 14]}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.007 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'nums': [15, 16, 17, 18, 19, 1, 2, 3]}
#
# Expected Output:
# 5
#
#
# Actual Output:
# 5
#
# Execution Time:
# 0.007 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'nums': [1, 2, 3, 4, 5, 6, 7, 8]}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'nums': [10, 1, 2, 3, 4, 5]}
#
# Expected Output:
# 1
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'nums': [2, 3, 4, 5, 1]}
#
# Expected Output:
# 4
#
#
# Actual Output:
# 4
#
# Execution Time:
# 0.005 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'nums': [2, 3, 4, 5, 0]}
#
# Expected Output:
# 4
#
#
# Actual Output:
# 4
#
# Execution Time:
# ...

# %% [markdown]
# # **Binary Search**

# %%
def count_rotations_binary(nums):
    if (len(nums)==0 or len(nums)==1) or (nums[len(nums)-1]>nums[0]):
      return 0
    lo = 0
    hi = len(nums)-1
    
    while lo<=hi:
        mid = (lo+hi)//2
        mid_number = nums[mid]
        
        # Uncomment the next line for logging the values and fixing errors.
        print("lo:", lo, ", hi:", hi, ", mid:", mid, ", mid_number:", mid_number)
        
        if mid>0 and nums[mid]<nums[mid-1]:
            # The middle position is the answer
            return mid
        
        elif nums[mid] > nums[0]: # Answer lies in the left half
            lo=mid+1
        else:
            # Answer lies in the right half
            hi = mid - 1
    
    return -1

# %%
binary_search_result = evaluate_test_cases(count_rotations_binary, tests)
# Out:
# TEST CASE #0
# lo: 0 , hi: 9 , mid: 4 , mid_number: 5
# lo: 0 , hi: 3 , mid: 1 , mid_number: 25
# lo: 2 , hi: 3 , mid: 2 , mid_number: 29
# lo: 3 , hi: 3 , mid: 3 , mid_number: 3
#
# Input:
# {'nums': [19, 25, 29, 3, 5, 6, 7, 9, 11, 14]}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 5.189 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# lo: 0 , hi: 7 , mid: 3 , mid_number: 18
# lo: 4 , hi: 7 , mid: 5 , mid_number: 1
#
# Input:
# {'nums': [15, 16, 17, 18, 19, 1, 2, 3]}
#
# Expected Output:
# 5
#
#
# Actual Output:
# 5
#
# Execution Time:
# 0.302 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'nums': [1, 2, 3, 4, 5, 6, 7, 8]}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# lo: 0 , hi: 5 , mid: 2 , mid_number: 2
# lo: 0 , hi: 1 , mid: 0 , mid_number: 10
#
# Input:
# {'nums': [10, 1, 2, 3, 4, 5]}
#
# Expected Output:
# 1
#
#
# Actual Output:
# -1
#
# Execution Time:
# ...
